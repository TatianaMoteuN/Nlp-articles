# %% [markdown]
# ### Using NLTK

# %%
#!pip3 install nltk

# %%
#import our librairies
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
#!pip3 install spacy
#!pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.0.0/en_core_web_md-2.0.0.tar.gz
#!pip3 install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz

# %%
#!python3 -m spacy validate

# %%
#!python3 -m spacy download en_core_web_sm

# %% [markdown]
# ## Information Extraction

# %%
#define our sentence
#text = 'The Mona Lisa is a 16th century oil painting created by Leonardo. It is held at the Louvre in Paris.'
text = 'The best of the New South Wales diamonds are harder and much whiter than the South African diamonds, and are classified as on a par with the best Brazilian gems, but no large specimens have yet been found.'

# %%
#we apply word tokenization and part of speech
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(text)
sent
# Out:
# [('The', 'DT'),
#  ('best', 'JJS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('New', 'NNP'),
#  ('South', 'NNP'),
#  ('Wales', 'NNP'),
#  ('diamonds', 'NNS'),
#  ('are', 'VBP'),
#  ('harder', 'JJR'),
#  ('and', 'CC'),
#  ('much', 'RB'),
#  ('whiter', 'JJR'),
#  ('than', 'IN'),
#  ('the', 'DT'),
#  ('South', 'JJ'),
#  ('African', 'JJ'),
#  ('diamonds', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('are', 'VBP'),
#  ('classified', 'VBN'),
#  ('as', 'IN'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('par', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('best', 'JJS'),
#  ('Brazilian', 'JJ'),
#  ('gems', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('no', 'DT'),
#  ('large', 'JJ'),
#  ('specimens', 'NNS'),
#  ('have', 'VBP'),
#  ('yet', 'RB'),
#  ('been', 'VBN'),
#  ('found', 'VBN'),
#  ('.', '.')]

# %% [markdown]
# ## Using Spacy

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
#we define our document
doc = nlp('The best of the New South Wales Diamonds are harder and much whiter than the South African Diamonds, and are classified as on a par with the best Brazilian gems, but no large specimens have yet been found.')

# %%
#print the entity level
print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('the New South Wales Diamonds', 'ORG'), ('the South African Diamonds', 'LOC'), ('Brazilian', 'NORP')]

# %%
#print token-level entity annotation
print([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(The, 'O', ''), (best, 'O', ''), (of, 'O', ''), (the, 'B', 'ORG'), (New, 'I', 'ORG'), (South, 'I', 'ORG'), (Wales, 'I', 'ORG'), (Diamonds, 'I', 'ORG'), (are, 'O', ''), (harder, 'O', ''), (and, 'O', ''), (much, 'O', ''), (whiter, 'O', ''), (than, 'O', ''), (the, 'B', 'LOC'), (South, 'I', 'LOC'), (African, 'I', 'LOC'), (Diamonds, 'I', 'LOC'), (,, 'O', ''), (and, 'O', ''), (are, 'O', ''), (classified, 'O', ''), (as, 'O', ''), (on, 'O', ''), (a, 'O', ''), (par, 'O', ''), (with, 'O', ''), (the, 'O', ''), (best, 'O', ''), (Brazilian, 'B', 'NORP'), (gems, 'O', ''), (,, 'O', ''), (but, 'O', ''), (no, 'O', ''), (large, 'O', ''), (specimens, 'O', ''), (have, 'O', ''), (yet, 'O', ''), (been, 'O', ''), (found, 'O', ''), (., 'O', '')]

# %% [markdown]
# ## Extracting entities from a blog

# %%
from bs4 import BeautifulSoup
import requests
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

ny_bb = url_to_string('https://www.mdanderson.org/publications/cancerwise/my-proton-therapy-treatment-for-prostate-cancer-during-the-coronavirus-covid-19-pandemic.h00-159381945.html')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 107

# %% [markdown]
# There are 107 enitites in the blog and they are represented as 8 unique labels

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'PERSON': 30,
#          'ORG': 36,
#          'DATE': 14,
#          'CARDINAL': 15,
#          'GPE': 8,
#          'PERCENT': 1,
#          'FAC': 2,
#          'MONEY': 1})

# %%
#let's show the two most frequent tokens
items = [x.text for x in article.ents]
Counter(items).most_common(2)
# Out:
# [('MD Anderson', 7), ('David Maddox', 4)]

# %%
#select randomly one sentence to learn more
sentences = [x for x in article.sents]
print(sentences[55])
# Out:
# As part of our mission to eliminate cancer, MD Anderson researchers conduct hundreds of clinical trials to test new treatments for both common and rare cancers.

# %%
#generate the raw markup
displacy.render(nlp(str(sentences[55])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">As part of our mission to eliminate cancer,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MD Anderson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  researchers conduct
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hundreds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of clinical trials to test new treatments for both common and rare cancers.</div></span>

# %%
#show how the sentences and its dependencies lokk like
displacy.render(nlp(str(sentences[55])), style='dep', jupyter = True, options = {'distance': 43})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4099f2f439b24c29a8d6a63263c9ca04-0" class="displacy" width="1168" height="287.5" direction="ltr" style="max-width: none; height: 287.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">As</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="93">part</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="93">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="136">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="136">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="179">our</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="179">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="222">mission</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="222">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="265">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="265">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="308">eliminate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="308">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="351">cancer,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="351">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="394">MD</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="394">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="437">Anderson</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="437">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="480">researchers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="480">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="523">conduct</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="523">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="566">hundreds</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="566">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="609">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="609">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="652">clinical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="652">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="695">trials</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="695">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="738">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="738">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="781">test</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="781">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="824">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="824">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="867">treatments</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="867">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="910">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="910">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="953">both</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="953">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="996">common</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="996">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="1039">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1039">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="1082">rare</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1082">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.5">
#     <tspan class="displacy-word" fill="currentColor" x="1125">cancers.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1125">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4099f2f439b24c29a8d6a63263c9ca04-0-0" stroke-width="2px" d="M70,152.5 C70,2.0 523.0,2.0 523.0,152.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4099f2f439b24c29a8d6a63263c9ca04-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.5 L62,142.5 78,142.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4099f2f439b24c29a8d6a63263c9ca04-0-1" stroke-width="2px" d="M70,152.5 C70,131.0 63.0,131.0 63.0,152.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4099f2f439b24c29a8d6a63263c9ca04-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M63.0,154.5 L71.0,142.5 55.0,142.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4099f2f439b24c29a8

# %%
#verbatim, extract part-of-speech and lemmatize the sentence
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[55])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('mission', 'NOUN', 'mission'),
#  ('eliminate', 'VERB', 'eliminate'),
#  ('cancer', 'NOUN', 'cancer'),
#  ('MD', 'PROPN', 'MD'),
#  ('Anderson', 'PROPN', 'Anderson'),
#  ('researchers', 'NOUN', 'researcher'),
#  ('conduct', 'VERB', 'conduct'),
#  ('hundreds', 'NOUN', 'hundred'),
#  ('clinical', 'ADJ', 'clinical'),
#  ('trials', 'NOUN', 'trial'),
#  ('test', 'VERB', 'test'),
#  ('new', 'ADJ', 'new'),
#  ('treatments', 'NOUN', 'treatment'),
#  ('common', 'ADJ', 'common'),
#  ('rare', 'ADJ', 'rare'),
#  ('cancers', 'NOUN', 'cancer')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[55])).ents])
# Out:
# {'MD Anderson': 'PERSON', 'hundreds': 'CARDINAL'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[55]])
# Out:
# [(As, 'O', ''), (part, 'O', ''), (of, 'O', ''), (our, 'O', ''), (mission, 'O', ''), (to, 'O', ''), (eliminate, 'O', ''), (cancer, 'O', ''), (,, 'O', ''), (MD, 'B', 'PERSON'), (Anderson, 'I', 'PERSON'), (researchers, 'O', ''), (conduct, 'O', ''), (hundreds, 'B', 'CARDINAL'), (of, 'O', ''), (clinical, 'O', ''), (trials, 'O', ''), (to, 'O', ''), (test, 'O', ''), (new, 'O', ''), (treatments, 'O', ''), (for, 'O', ''), (both, 'O', ''), (common, 'O', ''), (and, 'O', ''), (rare, 'O', ''), (cancers, 'O', ''), (., 'O', '')]

# %%
#visualize the entity of the entire blog
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> My proton therapy for prostate cancer during the coronavirus (COVID-19) pandemic | MD Anderson Cancer Center Skip to Content
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MyChart Log
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in to our secure, personalized website to manage your care (formerly
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     myMDAnderson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ). Request an Appointment Request an Appointment If you are ready to make an appointment, select a button on the right. If you have questions about
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MD Anderson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s appointment process, our information page may be the best place to start. Appointment Information  New Patients  Current Patients  Referring Physicians
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Today   Menu Close Locations Careers Contact Us Our Doctors Languages Español عربى 中文
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Türkçe Clear Go
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  close Clear Go
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MyChart Donate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Locations Careers Contact Us Languages Español عربى 中文
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Türkçe Request
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  an Appointment Request an Appointment New Patients Current Patients Referring Physicians Patients &amp; Family Becoming Our Patient Becoming Our Patient Becoming Our Patient Home Why MD
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anderson Planning for Care Getting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to MD
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anderson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  While You're Here International Center Services and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amenities Insurance &amp; Billing Diagnosis &amp; Treatment Diagnosis &amp; Treatment Diagnosis &amp;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Treatment Home Cancer Types A New Diagnosis Treatment Options Care Centers &amp; Clinics Emotional &amp; Physical Effects Patient Support Clinical Trials Supporting a Loved One Supporting a Loved One Supporting a Loved One Home Caregiver Roles &amp; Challenges Children and Teens Taking Care of Yourself Helping an MD
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anderson Patient
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Dealing with Loss Life After Cancer Life After Cancer Life After Cancer Home Legal &amp; Financial Impacts of Cancer Social &amp; Emotional Impacts of Cancer Follow-up Care Long-Term Effects of Cancer Survivorship Week Request an Appointment Current Patients Find information and resources for current and returning patients. Clinical Trials Learn about clinical trials at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MD Anderson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and search our database for open studies.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prevention &amp; Screening Manage Your Risk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Manage Your Risk Manage Your Risk Home Smoking &amp; Tobacco Diet Physical Activity Skin Safety HPV Hepatitis Family History Family History Family History Home Genetic Testing Hereditary Cancer Syndromes Genetic Counseling and Testing FAQs Cancer Screenings Cancer Screenings Cancer Screenings Home Breast Cancer Screening Cervical Cancer Screening Colorectal Cancer Screening Exams Endometrial Cancer Screening Exams Liver Cancer Screening Exams Lung Cancer Screening Exams Mobile Mammography Ovarian Cancer Screening Exams Prostate Cancer Screening Exams Skin Cancer Screening Exams Women's Screening Exams Men's Screening Exams   Cancer Prevention Center
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Lyda Hill Cancer Prevention Center
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  provides cancer risk assessment, screening and diagnostic services.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donors &amp; Volunteers Donate Donate Donate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark
